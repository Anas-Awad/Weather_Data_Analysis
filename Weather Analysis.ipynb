# %% [markdown]
# ## import necessary libraries

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as pls
# %matplotlib inline
sns.set_theme(context = 'poster' , style = 'ticks' , palette = 'magma' , font_scale = 0.7 , rc = {'figure.figsize':[22, 10]})

# %% [markdown]
# ### Read the Dataset

# %%
df = pd.read_csv('Weather Data.csv')
df
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %% [markdown]
# ## How to Analyze Dataset ?

# %% [markdown]
# ### .head() - It shows the first N rows in the data (by default, N=5).

# %%
df.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %% [markdown]
# ### .shape - It shows the total no. of rows and no. of columns of the dataframe

# %%
df.shape
# Out:
# (8784, 8)

# %% [markdown]
# ### .index - This attribute provides the index of the dataframe

# %%
df.index
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %% [markdown]
# ### .columns - It shows the name of each column

# %%
df.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %% [markdown]
# ### .dtypes - It shows the data-type of each column

# %%
df.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %% [markdown]
# ### unique() - In a column, it shows all the unique values. It can be applied on a single column only, not on the whole dataframe.

# %%
df.Weather.unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %% [markdown]
# ### nunique() - It shows the total no. of unique values in each column. It can be applied on a single column as well as on the whole dataframe.

# %%
df.Weather.nunique()
# Out:
# 50

# %% [markdown]
# ### .count - It shows the total no. of non-null values in each column. It can be applied on a single column as well as on the whole dataframe.

# %%
df.count()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %% [markdown]
# ### value_counts - In a column, it shows all the unique values with their count. It can be applied on a single column only.

# %%
df.Weather.value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %% [markdown]
# ### .info() - Provides basic information about the dataframe.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %% [markdown]
# ### Q. 1)  Find all the unique 'Wind Speed' values in the data.

# %%
df['Wind Speed_km/h'].nunique()
# Out:
# 34

# %%
df['Wind Speed_km/h'].unique()
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2],
#       dtype=int64)

# %%
sns.histplot(data=df,x= 'Wind Speed_km/h',kde=True)
# Out:
# <AxesSubplot:xlabel='Wind Speed_km/h', ylabel='Count'>

# %% [markdown]
# ### Q. 2) Find the number of times when the 'Weather is exactly Clear'.

# %%
# method 1 using value_counts()
x = df.Weather.value_counts().head()
x
# Out:
# Mainly Clear     2106
# Mostly Cloudy    2069
# Cloudy           1728
# Clear            1326
# Snow              390
# Name: Weather, dtype: int64

# %%
# 2- filterig
print(f"times that the weather is clear  = {df[df['Weather'] == 'Clear'].shape[0]}")
# Out:
# times that the weather is clear  = 1326

# %%
# 3- using groupby()
y= df.groupby('Weather')
y['Weather'].count().sort_values(ascending = False).head()
# Out:
# Weather
# Mainly Clear     2106
# Mostly Cloudy    2069
# Cloudy           1728
# Clear            1326
# Snow              390
# Name: Weather, dtype: int64

# %%
# 3- using groupby() & get_group()
y= df.groupby('Weather')
y.get_group('Clear')
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
#4- using seaborn visualization
sns.set_style('darkgrid')
sns.countplot(data= df[df['Weather'].isin(x.index)], x= 'Weather',order=x.index)
# Out:
# <AxesSubplot:xlabel='Weather', ylabel='count'>

# %% [markdown]
# ### Q. 3) Find the number of times when the 'Wind Speed was exactly 4 km/h'.

# %%
# 1- using value_counts()
x = df['Wind Speed_km/h'].value_counts().head(10).sort_index()
x
# Out:
# 4     474
# 6     609
# 7     677
# 9     830
# 11    791
# 13    735
# 15    719
# 17    666
# 19    616
# 20    496
# Name: Wind Speed_km/h, dtype: int64

# %%
#using gorupby()
y = df.groupby('Wind Speed_km/h')
y['Wind Speed_km/h'].count().sort_values(ascending = True).tail(10)
# Out:
# Wind Speed_km/h
# 4     474
# 20    496
# 6     609
# 19    616
# 17    666
# 7     677
# 15    719
# 13    735
# 11    791
# 9     830
# Name: Wind Speed_km/h, dtype: int64

# %%
#using gorupby() & get_group()
y = df.groupby('Wind Speed_km/h')
y.get_group(4).shape[0]
# Out:
# 474

# %%
# filtering 
df[df['Wind Speed_km/h'] == 4].shape[0]
# Out:
# 474

# %%
# visualize using seaborn 
sns.set_style('darkgrid')
sns.countplot(data= df[df['Wind Speed_km/h'].isin(x.index)], x= 'Wind Speed_km/h',order=x.index)
# Out:
# <AxesSubplot:xlabel='Wind Speed_km/h', ylabel='count'>

# %% [markdown]
# ### Q. 4) Find out all the Null Values in the data.

# %%
df.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
df.isna().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
df.notnull().sum()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %%
df.notna().sum()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %% [markdown]
# ### Q. 5) Rename the column name 'Weather' of the dataframe to 'Weather Condition'.

# %%
df.rename(columns= {'Weather': 'Weather Condition'},inplace=True)

# %%
df.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather Condition
# 0            8.0     101.24               Fog
# 1            8.0     101.24               Fog

# %% [markdown]
# ### Q. 6) What is the mean 'Visibility' ?

# %%
df.Visibility_km.mean()
# Out:
# 27.66444672131151

# %%
df.Visibility_km.describe()['mean']
# Out:
# 27.66444672131151

# %% [markdown]
# ### Q. 7) What is the Standard Deviation of 'Pressure'  in this data?

# %%
# 1st
df.Press_kPa.std()
# Out:
# 0.8440047459486474

# %%
# 2nd
df.Press_kPa.describe()['std']
# Out:
# 0.8440047459486474

# %% [markdown]
# ### Q. 8) What is the Variance of 'Relative Humidity' in this data ?

# %%
df.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather Condition
# 0            8.0     101.24               Fog
# 1            8.0     101.24               Fog

# %%
# 1st
df['Rel Hum_%'].var()
# Out:
# 286.2485501984998

# %%
# 2nd
df['Rel Hum_%'].std() ** 2
# Out:
# 286.24855019849986

# %% [markdown]
# ### Q. 9) Find all instances when 'Snow' was recorded.

# %%
# filtering
df[df['Weather Condition'] == 'Snow']
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 55       1/3/2012 7:00   -14.0             -19.5         63               19
# 84      1/4/2012 12:00   -13.7             -21.7         51               11
# 86      1/4/2012 14:00   -11.3             -19.0         53                7
# 87      1/4/2012 15:00   -10.2             -16.3         61               11
# 88      1/4/2012 16:00    -9.4             -15.5         61               13
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
# value_counts()
df['Weather Condition'].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
# group_by & get_group
df.groupby('Weather Condition').get_group('Snow')
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 55       1/3/2012 7:00   -14.0             -19.5         63               19
# 84      1/4/2012 12:00   -13.7             -21.7         51               11
# 86      1/4/2012 14:00   -11.3             -19.0         53                7
# 87      1/4/2012 15:00   -10.2             -16.3         61               11
# 88      1/4/2012 16:00    -9.4             -15.5         61               13
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
# str.contains
df[df['Weather Condition'].str.contains('Snow')].head(50)
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 41   1/2/2012 17:00    -2.1              -9.5         57               22
# 44   1/2/2012 20:00    -5.6             -13.4         54               24
# 45   1/2/2012 21:00    -5.8             -12.8         58               26
# 47   1/2/2012 23:00    -7.4             -14.1         59               17
# 48    1/3/2012 0:00    -9.0             -16.0         57               28
# 50    1/3/2012 2:00   -10.5             -15.8         65               22
# 51    1/3/2012 3:00   -11.3             -18.7         54               33
# 53    1/3/2012 5:00   -12.9             -19.1         60               22
# 54    1/3/2012 6:00   -13.3             -19.3         61               19
# 55    1/3/2012 7:00   -14.0             -19.5         63               19
# 84   1/4/2012 12:00   -13.7             -21.7         51               11
# 86   1/4/2012 14:00   -11.3             -19.0         53                7
# ...

# %%
# isin()
df[df['Weather Condition'].isin(['Snow'])]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 55       1/3/2012 7:00   -14.0             -19.5         63               19
# 84      1/4/2012 12:00   -13.7             -21.7         51               11
# 86      1/4/2012 14:00   -11.3             -19.0         53                7
# 87      1/4/2012 15:00   -10.2             -16.3         61               11
# 88      1/4/2012 16:00    -9.4             -15.5         61               13
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %% [markdown]
# ### Q. 10) Find all instances when 'Wind Speed is above 24' and 'Visibility is 25'.

# %%
# filtering 
df[(df['Wind Speed_km/h'] > 24) & (df['Visibility_km'] == 25)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 23      1/1/2012 23:00     5.3               2.0         79               30
# 24       1/2/2012 0:00     5.2               1.5         77               35
# 25       1/2/2012 1:00     4.6               0.0         72               39
# 26       1/2/2012 2:00     3.9              -0.9         71               32
# 27       1/2/2012 3:00     3.7              -1.5         69               33
# ...                ...     ...               ...        ...              ...
# 8705  12/28/2012 17:00    -8.6             -12.0         76               26
# 8753  12/30/2012 17:00   -12.1             -15.8         74               28
# 8755  12/30/2012 19:00   -13.4             -16.5         77               26
# 8759  12/30/2012 23:00   -12.1             -15.1         78               28
# 8760   12/31/2012 0:00   -11.1             -14.4         77               26
#
# ...

# %% [markdown]
# ### Q. 11) What is the Mean value of each Feature against each 'Weather Condition ?

# %%
x = df.groupby('Weather Condition')
x.mean().T
# Out:
# Weather Condition       Clear      Cloudy     Drizzle  Drizzle,Fog  \
# Temp_C               6.825716    7.970544    7.353659     8.067500
# Dew Point Temp_C     0.089367    2.375810    5.504878     7.033750
# Rel Hum_%           64.497738   69.592593   88.243902    93.275000
# Wind Speed_km/h     10.557315   16.127315   16.097561    11.862500
# Visibility_km       30.153243   26.625752   17.931707     5.257500
# Press_kPa          101.587443  100.911441  100.435366   100.786625
#
# Weather Condition  Drizzle,Ice Pellets,Fog  Drizzle,Snow  Drizzle,Snow,Fog  \
# Temp_C                                0.40          1.05          0.693333
# Dew Point Temp_C                     -0.70          0.15          0.120000
# Rel Hum_%                            92.00         93.50         95.866667
# Wind Speed_km/h                      20.00         14.00         15.533333
# Visibility_km                         4.00         10.50          5.513333
# ...

# %% [markdown]
# ### Q. 12) What is the Minimum & Maximum value of each column against each 'Weather Condition ?

# %%
x = df.groupby('Weather Condition')
x.min().T
# Out:
# Weather Condition           Clear          Cloudy          Drizzle  \
# Date/Time          1/11/2012 1:00  1/1/2012 17:00  1/23/2012 21:00
# Temp_C                      -23.3           -21.4              1.1
# Dew Point Temp_C            -28.5           -26.8             -0.2
# Rel Hum_%                      20              18               74
# Wind Speed_km/h                 0               0                0
# Visibility_km                11.3            11.3              6.4
# Press_kPa                   99.52           98.39            97.84
#
# Weather Condition      Drizzle,Fog Drizzle,Ice Pellets,Fog      Drizzle,Snow  \
# Date/Time          1/23/2012 20:00         12/17/2012 9:00  12/17/2012 15:00
# Temp_C                         0.0                     0.4               0.9
# Dew Point Temp_C              -1.6                    -0.7               0.1
# Rel Hum_%                       85                      92                92
# ...

# %%
x.max().T
# Out:
# Weather Condition          Clear          Cloudy         Drizzle  \
# Date/Time          9/9/2012 5:00  9/9/2012 23:00  9/30/2012 3:00
# Temp_C                      32.8            30.5            18.8
# Dew Point Temp_C            20.4            22.6            17.7
# Rel Hum_%                     99              99              96
# Wind Speed_km/h               33              54              30
# Visibility_km               48.3            48.3            25.0
# Press_kPa                 103.63          103.65          101.56
#
# Weather Condition     Drizzle,Fog Drizzle,Ice Pellets,Fog      Drizzle,Snow  \
# Date/Time          9/30/2012 2:00         12/17/2012 9:00  12/19/2012 18:00
# Temp_C                       19.9                     0.4               1.2
# Dew Point Temp_C             19.1                    -0.7               0.2
# Rel Hum_%                     100                      92                95
# ...

# %% [markdown]
# ### Q. 13) Show all the Records where Weather Condition is Fog.

# %%
df[df['Weather Condition'] == 'Fog']
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# 5        1/1/2012 5:00    -1.4              -3.3         87                9
# 6        1/1/2012 6:00    -1.5              -3.1         89                7
# ...                ...     ...               ...        ...              ...
# 8716   12/29/2012 4:00   -16.0             -17.2         90                6
# 8717   12/29/2012 5:00   -14.8             -15.9         91                4
# 8718   12/29/2012 6:00   -13.8             -15.3         88                4
# 8719   12/29/2012 7:00   -14.8             -16.4         88                7
# 8722  12/29/2012 10:00   -12.0             -13.3         90                7
#
# ...

# %% [markdown]
# ### Q. 14) Find all instances when 'Weather is Clear' or 'Visibility is above 40'.

# %%
df[(df['Weather Condition'] == 'Clear') | (df['Visibility_km'] > 40)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 106     1/5/2012 10:00    -6.0             -10.0         73               17
# 107     1/5/2012 11:00    -5.6             -10.2         70               22
# 108     1/5/2012 12:00    -4.7              -9.6         69               20
# 109     1/5/2012 13:00    -4.4              -9.7         66               26
# ...                ...     ...               ...        ...              ...
# 8749  12/30/2012 13:00   -12.4             -16.2         73               37
# 8750  12/30/2012 14:00   -11.8             -16.1         70               37
# 8751  12/30/2012 15:00   -11.3             -15.6         70               32
# 8752  12/30/2012 16:00   -11.4             -15.5         72               26
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
# ...

# %% [markdown]
# ### Q. 15) Find all instances when :
# * A. 'Weather is Clear' and 'Relative Humidity is greater than 50'
# * or B. 'Visibility is above 40

# %%
df[((df['Weather Condition'] == 'Clear') & (df['Rel Hum_%'] > 50)) | ( df['Visibility_km'] > 40)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 106     1/5/2012 10:00    -6.0             -10.0         73               17
# 107     1/5/2012 11:00    -5.6             -10.2         70               22
# 108     1/5/2012 12:00    -4.7              -9.6         69               20
# 109     1/5/2012 13:00    -4.4              -9.7         66               26
# 110     1/5/2012 14:00    -5.1             -10.7         65               22
# ...                ...     ...               ...        ...              ...
# 8749  12/30/2012 13:00   -12.4             -16.2         73               37
# 8750  12/30/2012 14:00   -11.8             -16.1         70               37
# 8751  12/30/2012 15:00   -11.3             -15.6         70               32
# 8752  12/30/2012 16:00   -11.4             -15.5         72               26
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
# ...

# %% [markdown]
# ### Q. 16) Convert the datetime to date time type and then get the average temp for each month

# %%
df['Date/Time'] = pd.to_datetime(df['Date/Time'])

# %%
month = {1:'January', 2:'February', 3: 'March', 4:'April', 5:'May', 6:'June', 7:'July',8:'August', 9:'September', 10:'October', 11:'November', 12:'December'}

# %%
df['Month'] = df['Date/Time'].dt.month.apply(lambda x: month[x])
df
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 0    2012-01-01 00:00:00    -1.8              -3.9         86
# 1    2012-01-01 01:00:00    -1.8              -3.7         87
# 2    2012-01-01 02:00:00    -1.8              -3.4         89
# 3    2012-01-01 03:00:00    -1.5              -3.2         88
# 4    2012-01-01 04:00:00    -1.5              -3.3         88
# ...                  ...     ...               ...        ...
# 8779 2012-12-31 19:00:00     0.1              -2.7         81
# 8780 2012-12-31 20:00:00     0.2              -2.4         83
# 8781 2012-12-31 21:00:00    -0.5              -1.5         93
# 8782 2012-12-31 22:00:00    -0.2              -1.8         89
# 8783 2012-12-31 23:00:00     0.0              -2.1         86
#
#       Wind Speed_km/h  Visibility_km  Press_kPa     Weather Condition  \
# 0                   4            8.0     101.24                   Fog
# 1                   4            8.0     101.24                   Fog
# ...

# %%
# Answer
df.groupby('Month')['Temp_C'].mean().sort_values(ascending = False)
# Out:
# Month
# July         22.790054
# August       22.279301
# June         20.134028
# September    16.484444
# May          16.237769
# October      10.954973
# April         7.009306
# March         3.121237
# November      0.931389
# December     -3.306317
# February     -4.225000
# January      -7.371505
# Name: Temp_C, dtype: float64

# %% [markdown]
# # Visualization Part

# %%
df
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %% [markdown]
# ## what is the mean of temperature per each weather (most 10 weahter)

# %%
x = df.groupby('Weather Condition')['Temp_C'].mean().sort_values(ascending = False).head(10)
x
# Out:
# Weather Condition
# Thunderstorms                              24.150000
# Thunderstorms,Rain Showers,Fog             21.600000
# Thunderstorms,Rain,Fog                     20.600000
# Thunderstorms,Rain                         20.433333
# Thunderstorms,Rain Showers                 20.037500
# Thunderstorms,Moderate Rain Showers,Fog    19.600000
# Rain Showers                               13.722340
# Rain Showers,Fog                           12.800000
# Mainly Clear                               12.558927
# Thunderstorms,Heavy Rain Showers           10.900000
# Name: Temp_C, dtype: float64

# %%
sns.barplot(data=df[df['Weather Condition'].isin(x.index)], x = 'Temp_C',y= 'Weather Condition',order=x.index )
# Out:
# <AxesSubplot:xlabel='Temp_C', ylabel='Weather Condition'>

# %% [markdown]
# ### what is the mean  of windspeed per each weather (most 10 weahter)

# %%
x = df.groupby('Weather Condition')['Wind Speed_km/h'].mean().sort_values(ascending = False).head(10)
x
# Out:
# Weather Condition
# Moderate Snow,Blowing Snow       40.000000
# Snow Pellets                     35.000000
# Snow,Blowing Snow                34.842105
# Moderate Snow                    33.750000
# Freezing Rain,Snow Grains        32.000000
# Rain,Snow                        28.388889
# Freezing Rain,Ice Pellets,Fog    28.000000
# Rain,Snow Grains                 26.000000
# Rain,Ice Pellets                 24.000000
# Snow,Ice Pellets                 23.833333
# Name: Wind Speed_km/h, dtype: float64

# %%
sns.barplot(data=df[df['Weather Condition'].isin(x.index)], x = 'Wind Speed_km/h',y= 'Weather Condition',order=x.index )
# Out:
# <AxesSubplot:xlabel='Wind Speed_km/h', ylabel='Weather Condition'>

# %% [markdown]
# ### what is the mean of humidity per each weather (most 10 weahter)

# %%
x = df.groupby('Weather Condition')['Rel Hum_%'].mean().sort_values(ascending = False).head(10)
x
# Out:
# Weather Condition
# Rain Showers,Fog                           96.000000
# Rain,Snow,Fog                              96.000000
# Drizzle,Snow,Fog                           95.866667
# Moderate Rain,Fog                          94.000000
# Drizzle,Snow                               93.500000
# Drizzle,Fog                                93.275000
# Rain,Fog                                   93.189655
# Thunderstorms,Moderate Rain Showers,Fog    93.000000
# Moderate Snow,Blowing Snow                 92.500000
# Fog                                        92.286667
# Name: Rel Hum_%, dtype: float64

# %%
sns.barplot(data=df[df['Weather Condition'].isin(x.index)], x = 'Rel Hum_%',y= 'Weather Condition',order=x.index )
# Out:
# <AxesSubplot:xlabel='Rel Hum_%', ylabel='Weather Condition'>

# %% [markdown]
# ### determine the max temperature for each weather and see which has a cold weather and wich is hot

# %%
x = df.groupby('Weather Condition')['Temp_C'].max().sort_values(ascending = False).head(10)
x
# Out:
# Weather Condition
# Mainly Clear                      33.0
# Clear                             32.8
# Mostly Cloudy                     32.4
# Cloudy                            30.5
# Thunderstorms                     26.7
# Rain Showers                      26.4
# Thunderstorms,Rain Showers        25.5
# Thunderstorms,Rain Showers,Fog    22.9
# Rain                              22.8
# Rain,Fog                          21.7
# Name: Temp_C, dtype: float64

# %%
hot = sns.barplot(data=df[df['Weather Condition'].isin(x.index)], x = 'Temp_C',y= 'Weather Condition',order=x.index,estimator=max )
hot.figure.suptitle('most 10 cold weahter')
# Out:
# Text(0.5, 0.98, 'most 10 cold weahter')

# %%
y = df.groupby('Weather Condition')['Temp_C'].min().sort_values(ascending = True).head(10)
y
# Out:
# Weather Condition
# Clear               -23.3
# Mostly Cloudy       -23.2
# Mainly Clear        -22.8
# Cloudy              -21.4
# Freezing Fog        -19.0
# Snow                -16.7
# Fog                 -16.0
# Snow Showers        -13.3
# Snow,Blowing Snow   -12.0
# Haze                -11.5
# Name: Temp_C, dtype: float64

# %%
cold = sns.barplot(data=df[df['Weather Condition'].isin(y.index)], x = 'Temp_C',y= 'Weather Condition',order=y.index,estimator=min)
cold.figure.suptitle('most 10 cold weahter')
# Out:
# Text(0.5, 0.98, 'most 10 cold weahter')

# %% [markdown]
# ### map the correlation between the numeric columns

# %%
map = df.iloc[:, 1:7]
corr_map = map.corr()

# %%
sns.heatmap(corr_map,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### By Anas Awad
